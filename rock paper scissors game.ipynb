# %%
print("Welcome to Rock Paper Scissor Game:")
a= int(input('''Enter your choice:
    1 Rock
    2 Scissor
    3 paper
    '''))
b=random.choice(["rock","paper","scissor"])
if (a ==1 and  b == "Scissor"):
        print("Bot choice is: ",b)
        print("You win")
elif (a == 1 and b == "paper"):
        print("Bot choice is: ",b)
        print("you loss")
elif (a == 1 and b == "rock"):
        print("Bot choice is: ",b)
        print("It is a draw")
elif (a == 3 and b == "rock"):
        print("Bot choice is: ",b)
        print("you win")
elif (a == 3 and b == "scissor"):
        print("Bot choice is: ",b)
        print("you loss")
elif (a== 3 and b == "paper"):
        print("Bot choice is: ",b)
        print("It is a draw")
elif (a== 2 and b == "paper"):
        print("Bot choice is: ",b)
        print("you win")
elif (a == 2 and b == "rock"):
        print("Bot choice is: ",b)
        print("you loss")
elif (a== 2 and b == "scissor"):
        print("Bot choice is: ",b)
        print("It is a draw")
else:
  print("Invalid choice")
# Out:
# Welcome to Rock Paper Scissor Game:
#
#   Game staart...
#   1 Yes
#   2 No | Exit
#   1
# Enter your choice:
#     1 Rock
#     2 Scissor
#     3 paper
#     2
# Bot choice is:  rock
# you loss

# %%
import random
print("Welcome to rock paper scissor :")
while True:
  ucount=0
  botcount=0
  uc=int(input('''
   Do you want to start the game
   1 Yes
   2 No | Exit
   '''))
  if uc==1:
    for i in range(1,6):
      a=int(input('''
      Enter your choice
      1 Rock
      2 Paper
      3 Scissor
      '''))
      b=random.choice(["rock","paper","scissor"])
      if a==1:
        a="rock"
      if a==2:
        a="paper"
      if a==3:
        a="scissor"
      if a==b:
        print("Your choice :",a)
        print("Bot choice :",b)
        print("It is a draw")
        ucount +=1
        botcount +=1
      elif(a=="rock" and b=="scissor") or (a=="paper" and b == "rock") or (a=="scissor" and b == "paper"):
        print("Your choice :",a)
        print("Bot choice :",b)
        print("You win")
        ucount +=1
      else:
        print("Your choice :",a)
        print("Bot choice :",b)
        print("Bot win")
        botcount +=1
  if ucount > botcount:
        print("\n You win the game")
        print("Your score :",ucount)
        print("Bot score :",botcount)
  elif ucount < botcount:
        print("\n Bot win the game")
        print("Your score :",ucount)
        print("Bot score",botcount)
  elif ucount == botcount:
        print("It is a draw")
        print("Your score :",ucount)
        print("Bot score :",botcount)
  else:
    break
# Out:
# Welcome to rock paper scissor :
#
#    Do you want to start the game
#    1 Yes
#    2 No | Exit
#    1
#
#       Enter your choice
#       1 Rock
#       2 Paper
#       3 Scissor
#       1
# Your choice : rock
# Bot choice : scissor
# You win
#
#       Enter your choice
#       1 Rock
#       2 Paper
#       3 Scissor
#       1
# Your choice : rock
# Bot choice : paper
# Bot win
#
#       Enter your choice
#       1 Rock
#       2 Paper
#       3 Scissor
#       3
# Your choice : scissor
# Bot choice : scissor
# It is a draw
#
#       Enter your choice
#       1 Rock
#       2 Paper
#       3 Scissor
#       1
# Your choice : rock
# Bot choice : paper
# Bot win
#
#       Enter your choice
#       1 Rock
#       2 Paper
#       3 Scissor
#       1
# Your choice : rock
# Bot choice : rock
# It is a draw
#
#  Bot win the game
# Your score : 3
# Bot score 4
# ---------------------------------------------------------------------------
# ...
